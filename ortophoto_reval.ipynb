# %% [markdown]
# # Ortophoto revalidation

# %% [markdown]
# reducing area duplications
#
# I 26
#
# MD

# %%
import pandas as pd
WHOLE_AREA = "ggs19-24wew.csv"
small_outer = 'small_outer_cells19-24.csv'

# %% [markdown]
# # whole

# %%
df = pd.read_csv(WHOLE_AREA)

# %%
df
# Out:
#         gml_id                               id  metadataproperty  \
# 0      ggs19.6   SkorowidzOrtofomapy2019.900962               NaN
# 1      ggs19.7   SkorowidzOrtofomapy2019.900969               NaN
# 2     ggs19.12   SkorowidzOrtofomapy2019.900889               NaN
# 3     ggs19.15   SkorowidzOrtofomapy2019.900943               NaN
# 4     ggs19.16   SkorowidzOrtofomapy2019.900952               NaN
# ..         ...                              ...               ...
# 581  ggs24.138  SkorowidzOrtofomapy2024.1322934               NaN
# 582  ggs24.139  SkorowidzOrtofomapy2024.1322846               NaN
# 583  ggs24.140  SkorowidzOrtofomapy2024.1322822               NaN
# 584  ggs24.141  SkorowidzOrtofomapy2024.1322935               NaN
# 585  ggs24.142  SkorowidzOrtofomapy2024.1322824               NaN
#
#      description_href  description_title  description_nilreason  description  \
# 0                 NaN                NaN                    NaN          NaN
# 1                 NaN                NaN                    NaN          NaN
# 2                 NaN                NaN                    NaN          NaN
# 3                 NaN                NaN                    NaN          NaN
# 4                 NaN                NaN                    NaN          NaN
# ..                ...                ...                    ...          ...
# 581               NaN                NaN                    NaN          NaN
# 582               NaN                NaN                    NaN          NaN
# 583               NaN                NaN                    NaN          NaN
# 584               NaN                NaN                    NaN          NaN
# 585               NaN                NaN                    NaN          NaN
#
#      descriptionreference_href  descriptionreference_title  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 581                        NaN                         NaN
# 582                        NaN                         NaN
# 583                        NaN                         NaN
# 584                        NaN                         NaN
# 585                        NaN                         NaN
#
#      descriptionreference_nilreason  ...             WAZNY_OD  WAZNY_DO  \
# 0                               NaN  ...  2012-02-25T00:00:00       NaN
# 1                               NaN  ...  2012-02-25T00:00:00       NaN
# 2                               NaN  ...  2012-02-25T00:00:00       NaN
# 3                               NaN  ...  2012-02-25T00:00:00       NaN
# 4                               NaN  ...  2012-02-25T00:00:00       NaN
# ..                              ...  ...                  ...       ...
# 581                             NaN  ...  2012-01-12T00:00:00       NaN
# 582                             NaN  ...  2012-01-12T00:00:00       NaN
# 583                             NaN  ...  2012-01-12T00:00:00       NaN
# 584                             NaN  ...  2012-01-12T00:00:00       NaN
# 585                             NaN  ...  2012-01-12T00:00:00       NaN
#
#               IIP_WERSJA  JPT_OPIS     JPT_ID  SHAPE_LENG  SHAPE_LE_1  \
# 0    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 1    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 2    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 3    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 4    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# ..                   ...       ...        ...         ...         ...
# 581  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 582  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 583  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 584  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 585  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
#
#     SHAPE_AREA     layer                                   path
# 0     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 1     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 2     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 3     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 4     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# ..         ...       ...                                    ...
# 581   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 582   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 583   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 584   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 585   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
#
# [586 rows x 91 columns]

# %% [markdown]
# # rm 0.1 px

# %%
df = df[df['piksel'] != 0.1]
df
# Out:
#         gml_id                               id  metadataproperty  \
# 0      ggs19.6   SkorowidzOrtofomapy2019.900962               NaN
# 1      ggs19.7   SkorowidzOrtofomapy2019.900969               NaN
# 2     ggs19.12   SkorowidzOrtofomapy2019.900889               NaN
# 3     ggs19.15   SkorowidzOrtofomapy2019.900943               NaN
# 4     ggs19.16   SkorowidzOrtofomapy2019.900952               NaN
# ..         ...                              ...               ...
# 581  ggs24.138  SkorowidzOrtofomapy2024.1322934               NaN
# 582  ggs24.139  SkorowidzOrtofomapy2024.1322846               NaN
# 583  ggs24.140  SkorowidzOrtofomapy2024.1322822               NaN
# 584  ggs24.141  SkorowidzOrtofomapy2024.1322935               NaN
# 585  ggs24.142  SkorowidzOrtofomapy2024.1322824               NaN
#
#      description_href  description_title  description_nilreason  description  \
# 0                 NaN                NaN                    NaN          NaN
# 1                 NaN                NaN                    NaN          NaN
# 2                 NaN                NaN                    NaN          NaN
# 3                 NaN                NaN                    NaN          NaN
# 4                 NaN                NaN                    NaN          NaN
# ..                ...                ...                    ...          ...
# 581               NaN                NaN                    NaN          NaN
# 582               NaN                NaN                    NaN          NaN
# 583               NaN                NaN                    NaN          NaN
# 584               NaN                NaN                    NaN          NaN
# 585               NaN                NaN                    NaN          NaN
#
#      descriptionreference_href  descriptionreference_title  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 581                        NaN                         NaN
# 582                        NaN                         NaN
# 583                        NaN                         NaN
# 584                        NaN                         NaN
# 585                        NaN                         NaN
#
#      descriptionreference_nilreason  ...             WAZNY_OD  WAZNY_DO  \
# 0                               NaN  ...  2012-02-25T00:00:00       NaN
# 1                               NaN  ...  2012-02-25T00:00:00       NaN
# 2                               NaN  ...  2012-02-25T00:00:00       NaN
# 3                               NaN  ...  2012-02-25T00:00:00       NaN
# 4                               NaN  ...  2012-02-25T00:00:00       NaN
# ..                              ...  ...                  ...       ...
# 581                             NaN  ...  2012-01-12T00:00:00       NaN
# 582                             NaN  ...  2012-01-12T00:00:00       NaN
# 583                             NaN  ...  2012-01-12T00:00:00       NaN
# 584                             NaN  ...  2012-01-12T00:00:00       NaN
# 585                             NaN  ...  2012-01-12T00:00:00       NaN
#
#               IIP_WERSJA  JPT_OPIS     JPT_ID  SHAPE_LENG  SHAPE_LE_1  \
# 0    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 1    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 2    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 3    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 4    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# ..                   ...       ...        ...         ...         ...
# 581  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 582  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 583  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 584  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 585  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
#
#     SHAPE_AREA     layer                                   path
# 0     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 1     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 2     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 3     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 4     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# ..         ...       ...                                    ...
# 581   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 582   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 583   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 584   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 585   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
#
# [506 rows x 91 columns]

# %% [markdown]
# # add 0.1 px

# %%
# sm = pd.read_csv(small_outer)
# sm

# %%
# df = pd.concat([df, sm])
# df

# %% [markdown]
# # urls

# %%
df = df.drop_duplicates('url_do_pobrania')

# %%
df
# Out:
#         gml_id                               id  metadataproperty  \
# 0      ggs19.6   SkorowidzOrtofomapy2019.900962               NaN
# 1      ggs19.7   SkorowidzOrtofomapy2019.900969               NaN
# 2     ggs19.12   SkorowidzOrtofomapy2019.900889               NaN
# 3     ggs19.15   SkorowidzOrtofomapy2019.900943               NaN
# 4     ggs19.16   SkorowidzOrtofomapy2019.900952               NaN
# ..         ...                              ...               ...
# 576  ggs24.130  SkorowidzOrtofomapy2024.1322839               NaN
# 578  ggs24.132  SkorowidzOrtofomapy2024.1322802               NaN
# 579  ggs24.134  SkorowidzOrtofomapy2024.1322819               NaN
# 580  ggs24.136  SkorowidzOrtofomapy2024.1322808               NaN
# 582  ggs24.139  SkorowidzOrtofomapy2024.1322846               NaN
#
#      description_href  description_title  description_nilreason  description  \
# 0                 NaN                NaN                    NaN          NaN
# 1                 NaN                NaN                    NaN          NaN
# 2                 NaN                NaN                    NaN          NaN
# 3                 NaN                NaN                    NaN          NaN
# 4                 NaN                NaN                    NaN          NaN
# ..                ...                ...                    ...          ...
# 576               NaN                NaN                    NaN          NaN
# 578               NaN                NaN                    NaN          NaN
# 579               NaN                NaN                    NaN          NaN
# 580               NaN                NaN                    NaN          NaN
# 582               NaN                NaN                    NaN          NaN
#
#      descriptionreference_href  descriptionreference_title  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 576                        NaN                         NaN
# 578                        NaN                         NaN
# 579                        NaN                         NaN
# 580                        NaN                         NaN
# 582                        NaN                         NaN
#
#      descriptionreference_nilreason  ...             WAZNY_OD  WAZNY_DO  \
# 0                               NaN  ...  2012-02-25T00:00:00       NaN
# 1                               NaN  ...  2012-02-25T00:00:00       NaN
# 2                               NaN  ...  2012-02-25T00:00:00       NaN
# 3                               NaN  ...  2012-02-25T00:00:00       NaN
# 4                               NaN  ...  2012-02-25T00:00:00       NaN
# ..                              ...  ...                  ...       ...
# 576                             NaN  ...  2012-01-12T00:00:00       NaN
# 578                             NaN  ...  2012-01-12T00:00:00       NaN
# 579                             NaN  ...  2012-01-12T00:00:00       NaN
# 580                             NaN  ...  2012-01-12T00:00:00       NaN
# 582                             NaN  ...  2012-01-12T00:00:00       NaN
#
#               IIP_WERSJA  JPT_OPIS     JPT_ID  SHAPE_LENG  SHAPE_LE_1  \
# 0    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 1    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 2    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 3    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 4    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# ..                   ...       ...        ...         ...         ...
# 576  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 578  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 579  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 580  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 582  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
#
#     SHAPE_AREA     layer                                   path
# 0     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 1     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 2     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 3     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 4     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# ..         ...       ...                                    ...
# 576   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 578   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 579   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 580   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 582   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
#
# [450 rows x 91 columns]

# %% [markdown]
# # RGB

# %%
df = df[df['kolor'] == 'RGB']
df
# Out:
#         gml_id                               id  metadataproperty  \
# 0      ggs19.6   SkorowidzOrtofomapy2019.900962               NaN
# 1      ggs19.7   SkorowidzOrtofomapy2019.900969               NaN
# 2     ggs19.12   SkorowidzOrtofomapy2019.900889               NaN
# 3     ggs19.15   SkorowidzOrtofomapy2019.900943               NaN
# 4     ggs19.16   SkorowidzOrtofomapy2019.900952               NaN
# ..         ...                              ...               ...
# 576  ggs24.130  SkorowidzOrtofomapy2024.1322839               NaN
# 578  ggs24.132  SkorowidzOrtofomapy2024.1322802               NaN
# 579  ggs24.134  SkorowidzOrtofomapy2024.1322819               NaN
# 580  ggs24.136  SkorowidzOrtofomapy2024.1322808               NaN
# 582  ggs24.139  SkorowidzOrtofomapy2024.1322846               NaN
#
#      description_href  description_title  description_nilreason  description  \
# 0                 NaN                NaN                    NaN          NaN
# 1                 NaN                NaN                    NaN          NaN
# 2                 NaN                NaN                    NaN          NaN
# 3                 NaN                NaN                    NaN          NaN
# 4                 NaN                NaN                    NaN          NaN
# ..                ...                ...                    ...          ...
# 576               NaN                NaN                    NaN          NaN
# 578               NaN                NaN                    NaN          NaN
# 579               NaN                NaN                    NaN          NaN
# 580               NaN                NaN                    NaN          NaN
# 582               NaN                NaN                    NaN          NaN
#
#      descriptionreference_href  descriptionreference_title  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 576                        NaN                         NaN
# 578                        NaN                         NaN
# 579                        NaN                         NaN
# 580                        NaN                         NaN
# 582                        NaN                         NaN
#
#      descriptionreference_nilreason  ...             WAZNY_OD  WAZNY_DO  \
# 0                               NaN  ...  2012-02-25T00:00:00       NaN
# 1                               NaN  ...  2012-02-25T00:00:00       NaN
# 2                               NaN  ...  2012-02-25T00:00:00       NaN
# 3                               NaN  ...  2012-02-25T00:00:00       NaN
# 4                               NaN  ...  2012-02-25T00:00:00       NaN
# ..                              ...  ...                  ...       ...
# 576                             NaN  ...  2012-01-12T00:00:00       NaN
# 578                             NaN  ...  2012-01-12T00:00:00       NaN
# 579                             NaN  ...  2012-01-12T00:00:00       NaN
# 580                             NaN  ...  2012-01-12T00:00:00       NaN
# 582                             NaN  ...  2012-01-12T00:00:00       NaN
#
#               IIP_WERSJA  JPT_OPIS     JPT_ID  SHAPE_LENG  SHAPE_LE_1  \
# 0    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 1    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 2    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 3    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# 4    2025-02-28T16:25:41       NaN  2763400.0    2.001624    2.001624
# ..                   ...       ...        ...         ...         ...
# 576  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 578  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 579  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 580  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
# 582  2025-02-28T16:25:41       NaN  2763406.0    1.470161    1.470161
#
#     SHAPE_AREA     layer                                   path
# 0     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 1     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 2     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 3     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# 4     0.094509  ggs19wew  C:/Users/admin/Downloads/ggs19wew.gml
# ..         ...       ...                                    ...
# 576   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 578   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 579   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 580   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
# 582   0.054325  ggs24wew  C:/Users/admin/Downloads/ggs24wew.gml
#
# [350 rows x 91 columns]

# %% [markdown]
# # check

# %%
cols = ['godlo', 'akt_rok', 'kolor', 'piksel', 'modul_archiwizacji']

# %%
df[cols].sort_values(by=['godlo', 'akt_rok'])
# Out:
#                godlo  akt_rok kolor  piksel modul_archiwizacji
# 56   N-34-49-B-d-2-4     2019   RGB    0.25             1:5000
# 93   N-34-49-B-d-2-4     2020   RGB    0.25             1:5000
# 227  N-34-49-B-d-2-4     2021   RGB    0.05             1:5000
# 244  N-34-49-B-d-2-4     2021   RGB    0.25             1:5000
# 380  N-34-49-B-d-2-4     2022   RGB    0.05             1:5000
# ..               ...      ...   ...     ...                ...
# 134  N-34-62-A-b-1-1     2021   RGB    0.05             1:5000
# 190  N-34-62-A-b-1-1     2021   RGB    0.25             1:5000
# 284  N-34-62-A-b-1-1     2022   RGB    0.05             1:5000
# 474  N-34-62-A-b-1-1     2023   RGB    0.25             1:5000
# 548  N-34-62-A-b-1-1     2024   RGB    0.05             1:5000
#
# [350 rows x 5 columns]

# %%
df.groupby('godlo').count()[['akt_rok', 'kolor', 'piksel', 'modul_archiwizacji']]
# Out:
#                  akt_rok  kolor  piksel  modul_archiwizacji
# godlo
# N-34-49-B-d-2-4        7      7       7                   7
# N-34-49-B-d-3-2        7      7       7                   7
# N-34-49-B-d-3-4        7      7       7                   7
# N-34-49-B-d-4-1        7      7       7                   7
# N-34-49-B-d-4-2        7      7       7                   7
# N-34-49-B-d-4-3        7      7       7                   7
# N-34-49-B-d-4-4        7      7       7                   7
# N-34-49-D-b-1-2        7      7       7                   7
# N-34-49-D-b-2-1        7      7       7                   7
# N-34-49-D-b-2-2        7      7       7                   7
# N-34-49-D-b-2-3        7      7       7                   7
# N-34-49-D-b-2-4        7      7       7                   7
# N-34-49-D-b-4-2        7      7       7                   7
# N-34-49-D-b-4-4        7      7       7                   7
# N-34-49-D-d-2-2        7      7       7                   7
# N-34-49-D-d-2-4        7      7       7                   7
# N-34-49-D-d-4-2        7      7       7                   7
# N-34-49-D-d-4-4        7      7       7                   7
# N-34-50-A-c-1-3        7      7       7                   7
# N-34-50-A-c-3-1        7      7       7                   7
# N-34-50-A-c-3-3        7      7       7                   7
# N-34-50-C-a-1-1        7      7       7                   7
# N-34-50-C-a-1-3        7      7       7                   7
# N-34-50-C-a-3-1        7      7       7                   7
# N-34-50-C-a-3-2        7      7       7                   7
# N-34-50-C-a-3-3        7      7       7                   7
# N-34-50-C-a-3-4        7      7       7                   7
# N-34-50-C-c-1-1        7      7       7                   7
# N-34-50-C-c-1-2        7      7       7                   7
# N-34-50-C-c-1-3        7      7       7                   7
# N-34-50-C-c-1-4        7      7       7                   7
# N-34-50-C-c-2-1        7      7       7                   7
# N-34-50-C-c-2-3        7      7       7                   7
# N-34-50-C-c-2-4        7      7       7                   7
# N-34-50-C-c-3-1        7      7       7                   7
# N-34-50-C-c-3-2        7      7       7                   7
# N-34-50-C-c-4-1        7      7       7                   7
# N-34-50-C-c-4-2        7      7       7                   7
# N-34-50-C-c-4-3        7      7       7                   7
# N-34-50-C-c-4-4        7      7       7                   7
# N-34-50-C-d-1-3        7      7       7                   7
# N-34-50-C-d-1-4        7      7       7                   7
# N-34-50-C-d-3-1        7      7       7                   7
# N-34-50-C-d-3-2        7      7       7                   7
# N-34-50-C-d-3-3        7      7       7                   7
# N-34-50-C-d-3-4        7      7       7                   7
# N-34-50-C-d-4-1        7      7       7                   7
# N-34-50-C-d-4-3        7      7       7                   7
# N-34-62-A-a-2-2        7      7       7                   7
# N-34-62-A-b-1-1        7      7       7                   7

# %%
df.groupby('akt_rok').count()[['kolor', 'piksel', 'modul_archiwizacji']]
# Out:
#          kolor  piksel  modul_archiwizacji
# akt_rok
# 2019        50      50                  50
# 2020        50      50                  50
# 2021       100     100                 100
# 2022        50      50                  50
# 2023        50      50                  50
# 2024        50      50                  50

# %% [markdown]
# ## yrs

# %%
df['akt_rok'].unique()
# Out:
# array([2019, 2020, 2021, 2022, 2023, 2024])

# %%
r = pd.DataFrame()
for rok in df['akt_rok'].unique():
    x = df[df['akt_rok'] == rok].groupby('piksel').count()[['akt_rok', 'kolor', 'modul_archiwizacji']]
    r = pd.concat([r, x])
r
# Out:
#         akt_rok  kolor  modul_archiwizacji
# piksel
# 0.25         50     50                  50
# 0.25         50     50                  50
# 0.05         50     50                  50
# 0.25         50     50                  50
# 0.05         50     50                  50
# 0.25         50     50                  50
# 0.05         50     50                  50

# %%
df[df['akt_rok'] == 2019].groupby('piksel').count()[['akt_rok', 'kolor', 'modul_archiwizacji']]
# Out:
#         akt_rok  kolor  modul_archiwizacji
# piksel
# 0.25         50     50                  50

# %%
df[df['akt_rok'] == 2020].groupby('piksel').count()[['akt_rok', 'kolor', 'modul_archiwizacji']]
# Out:
#         akt_rok  kolor  modul_archiwizacji
# piksel
# 0.25         50     50                  50

# %%
df[df['akt_rok'] == 2021].groupby('piksel').count()[['akt_rok', 'kolor', 'modul_archiwizacji']]
# Out:
#         akt_rok  kolor  modul_archiwizacji
# piksel
# 0.05         50     50                  50
# 0.25         50     50                  50

# %%
df[df['akt_rok'] == 2022].groupby('piksel').count()[['akt_rok', 'kolor', 'modul_archiwizacji']]
# Out:
#         akt_rok  kolor  modul_archiwizacji
# piksel
# 0.05         50     50                  50

# %%
df[df['akt_rok'] == 2023].groupby('piksel').count()[['akt_rok', 'kolor', 'modul_archiwizacji']]
# Out:
#         akt_rok  kolor  modul_archiwizacji
# piksel
# 0.25         50     50                  50

# %%
df[df['akt_rok'] == 2024].groupby('piksel').count()[['akt_rok', 'kolor', 'modul_archiwizacji']]
# Out:
#         akt_rok  kolor  modul_archiwizacji
# piksel
# 0.05         50     50                  50

# %% [markdown]
# ## px

# %%
df.groupby('piksel').count()[['akt_rok', 'kolor', 'modul_archiwizacji']]
# Out:
#         akt_rok  kolor  modul_archiwizacji
# piksel
# 0.05        150    150                 150
# 0.25        200    200                 200

# %%
df.groupby('piksel')[['akt_rok']].median()
# Out:
#         akt_rok
# piksel
# 0.05     2022.0
# 0.25     2020.5

# %% [markdown]
# # save csv

# %%
df.to_csv('new_ggs_50_imgs.csv')
